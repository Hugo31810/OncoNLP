# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath("../Code"))
import preproc

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],0)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_0.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],1)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_1.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],2)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_2.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],3)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_3.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],4)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_4.csv', index=False)

# %% [markdown]
# ### EDA (textos preprocesados)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_0.csv')
df2 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_1.csv')
df3 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_2.csv')
df4 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_3.csv')
df5 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_4.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df1 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_0.csv')
#       5 df2 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_1.csv')
#       6 df3 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_2.csv')
#       7 df4 = pd.read_csv('../Data/processed/tcga_simple_train_preprocessed_3.csv')
#
# ...

# %%
df1['text_length'] = df1['text'].apply(lambda x: len(x.split()))

df1['text_length'].hist(bins=50)
plt.title("Longitud de los textos: Preprocesamiento 0")
plt.show()

# %%
df2['text_length'] = df2['text'].apply(lambda x: len(x.split()))

df2['text_length'].hist(bins=50)
plt.title("Longitud de los textos: Preprocesamiento 1")
plt.show()

# %%
df3['text_length'] = df3['text'].apply(lambda x: len(x.split()))

df3['text_length'].hist(bins=50)
plt.title("Longitud de los textos: Preprocesamiento 2")
plt.show()

# %%
df4['text_length'] = df4['text'].apply(lambda x: len(x.split()))

df4['text_length'].hist(bins=50)
plt.title("Longitud de los textos: Preprocesamiento 3")
plt.show()

# %%
df5['text_length'] = df5['text'].apply(lambda x: len(x.split()))

df5['text_length'].hist(bins=50)
plt.title("Longitud de los textos: Preprocesamiento 4")
plt.show()
