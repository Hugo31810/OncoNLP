# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath("../Code"))
import preproc

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],0)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_0.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],1)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_1.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],2)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_2.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],3)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_3.csv', index=False)

df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
df["text"] = preproc.preprocesamiento(df["text"],4)

df.to_csv('../Data/processed/tcga_simple_train_preprocessed_4.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#       9
#      10 df.to_csv('../Data/processed/tcga_simple_train_preprocessed_0.csv', index=False)
#      11
#      12 df = pd.read_csv('../Data/raw/tcga_simple_train.csv')
# ---> 13 df["text"] = preproc.preprocesamiento(df["text"],1)
#      14
#      15 df.to_csv('../Data/processed/tcga_simple_train_preprocessed_1.csv', index=False)
#      16
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\Code\preproc.py:11, in preprocesamiento(textos, id)
#       8 docs = nlp.pipe(textos, disable=["ner"], batch_size=50)
#       9 resultados = []
# ---> 11 for doc in docs:
#      12     match id:
#      13         case 1:
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\.venv\Lib\site-packages\spacy\language.py:1618, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1616     for pipe in pipes:
#    1617         docs = pipe(docs)
# -> 1618 for doc in docs:
#    1619     yield doc
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\.venv\Lib\site-packages\spacy\util.py:1763, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1753 def _pipe(
#    1754     docs: Iterable["Doc"],
#    1755     proc: "PipeCallable",
#    (...)   1760     kwargs: Mapping[str, Any],
#    1761 ) -> Iterator["Doc"]:
#    1762     if hasattr(proc, "pipe"):
# -> 1763         yield from proc.pipe(docs, **kwargs)
#    1764     else:
#    1765         # We added some args for pipe that __call__ doesn't expect.
#    1766         kwargs = dict(kwargs)
#
# File spacy/pipeline/pipe.pyx:48, in pipe()
# ---> 48 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\.venv\Lib\site-packages\spacy\util.py:1763, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1753 def _pipe(
#    1754     docs: Iterable["Doc"],
#    1755     proc: "PipeCallable",
#    (...)   1760     kwargs: Mapping[str, Any],
#    1761 ) -> Iterator["Doc"]:
#    1762     if hasattr(proc, "pipe"):
# -> 1763         yield from proc.pipe(docs, **kwargs)
#    1764     else:
#    1765         # We added some args for pipe that __call__ doesn't expect.
#    1766         kwargs = dict(kwargs)
#
# File spacy/pipeline/pipe.pyx:50, in pipe()
# ---> 50 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\.venv\Lib\site-packages\spacy\pipeline\attributeruler.py:131, in AttributeRuler.__call__(self, doc)
#     129 error_handler = self.get_error_handler()
#     130 try:
# --> 131     matches = self.match(doc)
#     132     self.set_annotations(doc, matches)
#     133     return doc
#
# File c:\Users\tcspo\Desktop\Codigo_Clases\PLN1\practica\OncoNLP\.venv\Lib\site-packages\spacy\pipeline\attributeruler.py:141, in AttributeRuler.match(self, doc)
#     138 matches = self.matcher(doc, allow_missing=True, as_spans=False)
#     139 # Sort by the attribute ID, so that later rules have precedence
#     140 matches = [
# --> 141     (int(self.vocab.strings[m_id]), m_id, s, e)
#     142     for m_id, s, e in matches  # type: ignore
#     143 ]
#     144 matches.sort()
#     145 return matches
#
# KeyboardInterrupt:
