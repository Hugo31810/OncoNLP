# %% [markdown]
# # Embeddings contextuales - BERT

# %%
import sys
import os

sys.path.append(os.path.abspath("../Code"))
import contextual_embeddings_bert as bert
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       1 import sys
#       2 import os
#       3
#       4 sys.path.append(os.path.abspath("../Code"))
# ----> 5 import contextual_embeddings_bert as bert
#
# File c:\Users\hugo\OneDrive - Universidad Rey Juan Carlos\Documentos\URJC\Apuntes GIA\3º GIA\PLNI\OncoNLP-1\Code\contextual_embeddings_bert.py:1
# ----> 1 import torch
#       2 import numpy as np
#       3 from transformers import AutoTokenizer, AutoModel
#
# File c:\Users\hugo\OneDrive - Universidad Rey Juan Carlos\Documentos\URJC\Apuntes GIA\3º GIA\PLNI\OncoNLP-1\.venv\Lib\site-packages\torch\__init__.py:2229
#    2222 from torch._compile import _disable_dynamo  # usort: skip
#    2224 ################################################################################
#    2225 # Import interface functions defined in Python
# ...
