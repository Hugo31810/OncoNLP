# %% [markdown]
# # Contextual embeddings - BERT

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../Code"))

import contextual_embeddings_bert as ceb
importlib.reload(ceb)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# <module 'contextual_embeddings_bert' from 'c:\\Users\\hugo\\PLN1\\OncoNLP\\Code\\contextual_embeddings_bert.py'>

# %% [markdown]
# Creamos los conjuntos de train y test

# %%
import pandas as pd
df = pd.read_csv('../Data/raw/tcga_simple_train.csv')

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['t'], test_size=0.2, random_state=42)

# %% [markdown]
# Creamos la representacion de embeddings contextuales BERT

# %%
X_train_bert = ceb.bert_embedding(X_train, 'mean')
X_test_bert = ceb.bert_embedding(X_test, 'mean')

# %% [markdown]
# Lo guardamos en un archiovo de numpy

# %%
import numpy as np
np.save("../Data/processed/bert_mean/X_train_bert_mean.npy", X_train_bert)
np.save("../Data/processed/bert_mean/X_test_bert_mean.npy", X_test_bert)

# %% [markdown]
# ---

# %% [markdown]
# # Contextual embeddings - ElMo

# %%
import sys
import os
import importlib
import pandas as pd

sys.path.append(os.path.abspath("../Code"))

import contextual_embeddings_elmo as ceelmo
ceelmo = importlib.reload(ceelmo)

# %%
X_train_elmo = ceelmo.elmo_embedding(X_train, pooling="mean")
X_test_elmo = ceelmo.elmo_embedding(X_test, pooling="mean")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 X_train_elmo = ceelmo.elmo_embedding(X_train, pooling="mean")
#       2 X_test_elmo = ceelmo.elmo_embedding(X_test, pooling="mean")
#
# File c:\Users\hugo\PLN1\OncoNLP\Code\contextual_embeddings_elmo.py:32, in elmo_embedding(texts, pooling)
#      29 texts = texts.astype(str).tolist() if hasattr(texts, "astype") else list(texts)
#      31 if pooling == "mean":
# ---> 32     return np.array([elmo_mean_embedding(text) for text in texts])
#      33 elif pooling == "max":
#      34     return np.array([elmo_max_embedding(text) for text in texts])
#
# File c:\Users\hugo\PLN1\OncoNLP\Code\contextual_embeddings_elmo.py:19, in elmo_mean_embedding(text)
#      18 def elmo_mean_embedding(text):
# ---> 19     embeddings = get_token_embeddings(text)
# ...
